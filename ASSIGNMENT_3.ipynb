# %% [markdown]
# <a href="https://colab.research.google.com/github/SAIPRIYADODDA/Assignment-3/blob/master/ASSIGNMENT_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.	Read mobile dataset using pandas, and preprocess it (fill null values).

# %%
import pandas as pd 
data=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
print(data)
data.describe()
# Out:
#      sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0           0        12        55  ...              2000             125         1
# 1           0         1        55  ...              2000             165         1
# 2           0         9        55  ...              2500             164         0
# 3           0         8        55  ...              3000             165         1
# 4           1         1        55  ...              3000             165         0
# ..        ...       ...       ...  ...               ...             ...       ...
# 104         3        10        14  ...              3410               8         1
# 105         0         5         3  ...              3600             101         1
# 106         3        10         6  ...              2750               1         1
# 107         3        10        12  ...              1810               7         1
# ...

# %%
data.isnull()
# Out:
#      sim_type  aperture  gpu_rank  ...  battery_capacity  processor_rank  is_liked
# 0       False     False     False  ...             False           False     False
# 1       False     False     False  ...             False           False     False
# 2       False     False     False  ...             False           False     False
# 3       False     False     False  ...             False           False     False
# 4       False     False     False  ...             False           False     False
# ..        ...       ...       ...  ...               ...             ...       ...
# 104     False     False     False  ...             False           False     False
# 105     False     False     False  ...             False           False     False
# 106     False     False     False  ...             False           False     False
# 107     False     False     False  ...             False           False     False
# ...

# %%
data.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               1
# stand_by_time                        3
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    2
# os                                   0
# phone_height                         1
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            1
# video_resolution                     1
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# ...

# %%
data['weight']=data['weight'].fillna(data['weight'].mean())
data['primary_camera_resolution']=data['primary_camera_resolution'].fillna(data['primary_camera_resolution'].mean())
data['front_camera_resolution']=data['front_camera_resolution'].fillna(data['front_camera_resolution'].mean())
data['talk_time']=data['talk_time'].fillna(data['talk_time'].mean())
data['phone_height']=data['phone_height'].fillna(data['phone_height'].mean())
data['no_of_reviews_in_gsmarena_in_week']=data['no_of_reviews_in_gsmarena_in_week'].fillna(data['no_of_reviews_in_gsmarena_in_week'].mean())
data['stand_by_time']=data['stand_by_time'].fillna(data['stand_by_time'].mean())
data['video_resolution']=data['video_resolution'].fillna(data['video_resolution'].mean())

# %%
data.isnull().sum()
# Out:
# sim_type                             0
# aperture                             0
# gpu_rank                             0
# weight                               0
# stand_by_time                        0
# processor_frequency                  0
# thickness                            0
# flash_type                           0
# front_camera_resolution              0
# auto_focus                           0
# screen_size                          0
# frames_per_second                    0
# FM                                   0
# no_of_reviews_in_gsmarena_in_week    0
# os                                   0
# phone_height                         0
# screen_protection                    0
# sim_size                             0
# price                                0
# talk_time                            0
# video_resolution                     0
# display_resolution                   0
# removable_battery                    0
# display_type                         0
# ...

# %% [markdown]
# 2.	Draw correlation graph for mobile price with all attributes.

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,0:1]
plt.xlabel("price")
plt.ylabel("sim_type")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,1:2]
plt.xlabel("price")
plt.ylabel("aperture")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,2:3]
plt.xlabel("price")
plt.ylabel("gpu_rank")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,4:5]
plt.xlabel("price")
plt.ylabel("stand_by_time")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,5:6]
plt.xlabel("price")
plt.ylabel("processor_frequency")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,6:7]
plt.xlabel("price")
plt.ylabel("thickness")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,7:8]
plt.xlabel("price")
plt.ylabel("flash_type")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,8:9]
plt.xlabel("price")
plt.ylabel("front_camera_resolution")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,9:10]
plt.xlabel("price")
plt.ylabel("auto_focus")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,10:11]
plt.xlabel("price")
plt.ylabel("screen_size")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,11:12]
plt.xlabel("price")
plt.ylabel("frames_per_second")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,12:13]
plt.xlabel("price")
plt.ylabel("FM")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,13:14]
plt.xlabel("price")
plt.ylabel("no_of_reviews_in_gsmarena_in_week")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,14:15]
plt.xlabel("price")
plt.ylabel("OS")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,15:16]
plt.xlabel("price")
plt.ylabel("phine_height")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,16:17]
plt.xlabel("price")
plt.ylabel("screen_protection")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,17:18]
plt.xlabel("price")
plt.ylabel("sim_size")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,19:20]
plt.xlabel("price")
plt.ylabel("talk_time")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,20:21]
plt.xlabel("price")
plt.ylabel("vedio_resolution")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,21:22]
plt.xlabel("price")
plt.ylabel("display_resolution")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,22:23]
plt.xlabel("price")
plt.ylabel("removable_battery")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,23:24]
plt.xlabel("price")
plt.ylabel("display_type")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,24:25]
plt.xlabel("price")
plt.ylabel("primary_camera")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,25:26]
plt.xlabel("price")
plt.ylabel("battery_type")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,26:27]
plt.xlabel("price")
plt.ylabel("ram_memory")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,27:28]
plt.xlabel("price")
plt.ylabel("internal_memory")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,28:29]
plt.xlabel("price")
plt.ylabel("brand_rank")
plt.plot(x,y,'')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,29:30]
plt.xlabel("price")
plt.ylabel("no_of_cores")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,30:31]
plt.xlabel("price")
plt.ylabel("micro_sd_slot")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,31:32]
plt.xlabel("price")
plt.ylabel("screen_pixel_density")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,32:33]
plt.xlabel("price")
plt.ylabel("water_proof_rate")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,33:34]
plt.xlabel("price")
plt.ylabel("phone_width")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,34:35]
plt.xlabel("price")
plt.ylabel("expandable_memory")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,35:36]
plt.xlabel("price")
plt.ylabel("version")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,36:37]
plt.xlabel("price")
plt.ylabel("usb_type")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,37:38]
plt.xlabel("price")
plt.ylabel("battery_capacity")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,38:39]
plt.xlabel("price")
plt.ylabel("processor_rank")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,38:39]
plt.xlabel("price")
plt.ylabel("processor_rank")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %%
import pandas as pd
import matplotlib.pyplot as plt
a=pd.read_csv('/content/drive/My Drive/mobile_cleaned-1549119762886.csv')
x=a.iloc[0:,18:19]
y=a.iloc[0:,39:40]
plt.xlabel("price")
plt.ylabel("is_linked")
plt.plot(x,y,'c')
plt.scatter(x,y)

# %% [markdown]
# 3.	Compute outer product of 2 vectors.
# Eg:
# original matrix:
# [[1, 0], [0, 1]]
# [[1, 2], [3, 4]]
# Outer product of the said two vectors:
# [[1 2 3 4]
#  [0 0 0 0]
#  [0 0 0 0]
#  [1 2 3 4]]

# %%
import numpy as np
a=[[1,0],[0,1]]
b=[[1,2],[3,4]]
result=np.outer(a,b)
print(result)
# Out:
# [[1 2 3 4]
#  [0 0 0 0]
#  [0 0 0 0]
#  [1 2 3 4]]

# %% [markdown]
# 4.	Write a NumPy program to compute the condition number of a given matrix.
# 	Original matrix:
# 	[[1 2]
# 	 [3 4]]
# 	Condition number of the said matrix:
# 	14.9330343737

# %%
import numpy.linalg as nl
a=[[1,2],[3,4]]
print("Original matrix is  : ")
print(a)
print("Condition number of given matrix is : ")
print(nl.cond(a))
# Out:
# Original matrix is  :
# [[1, 2], [3, 4]]
# Condition number of given matrix is :
# 14.933034373659268

# %% [markdown]
# 5. write a NumPy program to compute the sum of the diagonal element of a given array(matrix).

# %%
a=[[1,1,1],[2,2,2],[3,3,3]]
print("Given matrix is : ")
print(a)
print("Sum of diagonal elements of the given matrix is : ")
print(np.trace(a))
# Out:
# Given matrix is :
# [[1, 1, 1], [2, 2, 2], [3, 3, 3]]
# Sum of diagonal elements of the given matrix is :
# 6
